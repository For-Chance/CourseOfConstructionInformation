# %% [markdown]
# <center>
# <h1>Python and Pandas - Introduction</h1>
# <h2>
# Charts - part 2
# </h2>
# Based on "Applied Plotting, Charting & Data Representation in Python" (Coursera)
# </center>

# %% [markdown]
# ## Subplots

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np

# %%
plt.figure()
plt.subplot(1, 2, 1)
linear_data = np.arange(1, 9)
plt.plot(linear_data, '-o')
exponential_data = linear_data ** 2

plt.subplot(1, 2, 2)
plt.plot(exponential_data, '-o')

# %%
plt.figure()
ax1 = plt.subplot(1, 2, 1)
plt.plot(linear_data, 'o')

plt.subplot(1, 2, 2, sharey = ax1)  # 'sharey' control the scale
plt.plot(exponential_data, '-x')

# %% [markdown]
# Same scale on y axes

# %%
fig, (
    (ax1, ax2, ax3),
    (ax4, ax5, ax6),
    (ax7, ax8, ax9)
) = plt.subplots(3, 3, sharex = True, sharey=True)

ax5.plot(linear_data, '-o')

# %% [markdown]
# ### More charts

# %% [markdown]
# ### Task 1
# Prepare the chart with two subplots (bar plots) that present data1 and data2 lists.
# - Subplots shall be arranged vertically (the second one below the first one)
# - Subplots shall share X axis
# - Add y labels ("Data 1" and "Data 2") to subplots

# %%
data1 = [2, 3, 5, 1, 2, 5, 2]
data2 = [3, 4, 1, -2, -1, 2, 1]

# %%
# Enter your code here
pos = np.arange(len(data1))
fig, (ax1, ax2) = plt.subplots(2, 1)
ax1.bar(pos, data1)
ax1.set_ylabel('Data 1')

ax2.bar(pos, data2)
ax2.set_ylabel('Data 2')
# Out:
# Text(0, 0.5, 'Data 2')

# %% [markdown]
# ## Histograms

# %%
plt.figure()
sample = np.random.normal(loc=0.0, scale=1.0, size=10000)
ax1 = plt.subplot(121)
plt.hist(sample)

ax2 = plt.subplot(122, sharey = ax1)
plt.hist(sample, bins=20)
# Out:
# (array([   6.,   19.,   38.,   92.,  224.,  405.,  720.,  990., 1220.,
#         1374., 1369., 1262.,  923.,  647.,  364.,  187.,   99.,   47.,
#           10.,    4.]),
#  array([-3.51740207, -3.16212493, -2.80684779, -2.45157064, -2.0962935 ,
#         -1.74101636, -1.38573922, -1.03046207, -0.67518493, -0.31990779,
#          0.03536936,  0.3906465 ,  0.74592364,  1.10120078,  1.45647793,
#          1.81175507,  2.16703221,  2.52230936,  2.8775865 ,  3.23286364,
#          3.58814078]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# ## Box plots

# %% [markdown]
# ##### Prepare and analyze data

# %%
import pandas as pd
normal_sample = np.random.normal(loc=0.0, scale=1.0, size=10000)
random_sample = np.random.random(size=10000)
gamma_sample = np.random.gamma(2, size=10000)

df = pd.DataFrame({'normal': normal_sample, 
                   'random': random_sample, 
                   'gamma': gamma_sample})

df.describe()
# Out:
#              normal        random         gamma
# count  10000.000000  10000.000000  10000.000000
# mean       0.002152      0.497140      2.003845
# std        0.994433      0.290366      1.402432
# min       -3.690627      0.000011      0.017645
# 25%       -0.661457      0.243798      0.967149
# 50%        0.001246      0.493656      1.691546
# 75%        0.668870      0.750798      2.700957
# max        4.288198      0.999950     10.356174

# %% [markdown]
# ### Task 2
# Prepare the chart with 3 subplots (histograms) that contain data from `df` dataframe.
# - Histograms shall be arranged horizontally (in one row)
# - Histograms shall contain 25 bins
# - Histograms shall share y axis
# - Histograms shall have titles

# %%
# Enter your code here
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, sharey = True)
ax1.hist(normal_sample, bins = 25)
ax1.set_title('normal hist')

ax2.hist(random_sample, bins = 25)
ax2.set_title('random hist')

ax3.hist(gamma_sample, bins = 25)
ax3.set_title('gamma hist')
# Out:
# Text(0.5, 1.0, 'gamma hist')

# %% [markdown]
# ##### Box Plot

# %%
plt.figure()
plt.boxplot(df['normal'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2387f127640>,
#   <matplotlib.lines.Line2D at 0x2387f127910>],
#  'caps': [<matplotlib.lines.Line2D at 0x2387f127be0>,
#   <matplotlib.lines.Line2D at 0x2387f127eb0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2387f10e1c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x2387f1571c0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2387f157490>],
#  'means': []}

# %% [markdown]
# Default size of the whisker is equal to 1.5 * IQR (InterQuartile Range)

# %%
plt.figure()
plt.boxplot(df['normal'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2387f1a20a0>,
#   <matplotlib.lines.Line2D at 0x2387f1a2370>],
#  'caps': [<matplotlib.lines.Line2D at 0x2387f1a2640>,
#   <matplotlib.lines.Line2D at 0x2387f1a2910>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2387f194d60>],
#  'medians': [<matplotlib.lines.Line2D at 0x2387f1a2be0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2387f1a2eb0>],
#  'means': []}

# %% [markdown]
# Whiskers can be set as relative values

# %%
plt.figure()
plt.boxplot(df['normal'], whis=[0.1, 99.9])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2387f20aa30>,
#   <matplotlib.lines.Line2D at 0x2387f20ad00>],
#  'caps': [<matplotlib.lines.Line2D at 0x2387f20afd0>,
#   <matplotlib.lines.Line2D at 0x2387f2182e0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2387f20a760>],
#  'medians': [<matplotlib.lines.Line2D at 0x2387f2185b0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2387f218880>],
#  'means': []}

# %% [markdown]
# Boxplots are often used to display different distributions at the same time.

# %%
# Out:
# ['normal', 'random', 'gamma']

# %%
plt.figure()
plt.boxplot([df['normal'], df['random'], df['gamma']], whis=[0, 100])
plt.xticks(ticks = [1, 2, 3], labels=df.columns)
# Out:
# ([<matplotlib.axis.XTick at 0x2387f7dcee0>,
#   <matplotlib.axis.XTick at 0x2387f7dceb0>,
#   <matplotlib.axis.XTick at 0x2387f80a190>],
#  [Text(1, 0, 'normal'), Text(2, 0, 'random'), Text(3, 0, 'gamma')])

# %% [markdown]
# #### Task 3
# Add title and x tick labels to the chart above. Use column names from `df` Dataframe as x tick tables.

# %%
# Enter your code here

# %% [markdown]
# ## Pandas

# %%
import pandas as pd

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
# use the 'seaborn-colorblind' style
plt.style.use('seaborn-colorblind')

# %% [markdown]
# ### DataFrame.plot

# %%
np.random.seed(123)

df = pd.DataFrame({'A': np.random.randn(365).cumsum(0), 
                   'B': np.random.randn(365).cumsum(0) + 20,
                   'C': np.random.randn(365).cumsum(0) - 20}, 
                  index=pd.date_range('1/1/2019', periods=365))
df.head()
# Out:
#                    A          B          C
# 2019-01-01 -1.085631  20.059291 -20.230904
# 2019-01-02 -0.088285  21.803332 -16.659325
# 2019-01-03  0.194693  20.835588 -17.055481
# 2019-01-04 -1.311601  21.255156 -17.093802
# 2019-01-05 -1.890202  21.462083 -19.518638

# %%
df.plot();

# %% [markdown]
# We can select which plot we want to use by passing it into the 'kind' parameter.

# %%
df.plot('A', 'B', kind='scatter');

# %% [markdown]
# #### Types of plots
# - Pandas offers different types of plots
# - instead of using argument `kind`, you can use `DataFrame.plot.kind` syntax.
#
# ##### list of available types:
# - `'line'` : line plot (default)
# - `'bar'` : vertical bar plot
# - `'barh'` : horizontal bar plot
# - `'hist'` : histogram
# - `'box'` : boxplot
# - `'kde'` : Kernel Density Estimation plot
# - `'density'` : same as 'kde'
# - `'area'` : area plot
# - `'pie'` : pie plot
# - `'scatter'` : scatter plot
# - `'hexbin'` : hexbin plot

# %% [markdown]
# Create a scatterplot from columns `A` (x axis) and `C` (y axis) that changes color and size of the dots based on the data from column `B`.

# %%
df.plot.scatter('A', 'C', c='B', s=df['B'], colormap='viridis')
# Out:
# <AxesSubplot:xlabel='A', ylabel='C'>

# %% [markdown]
# `DataFrame.plot` is using `matplotlib.pyplot`. You can modify the `DataFrame.plot` charts in the same way that you modify `pyplot` charts.

# %%
# ax = df.plot.scatter('A', 'C', c='B', s=df['B'], colormap='viridis')
# ax.set_aspect('euqal')

# %% [markdown]
# ### More `df.plot` examples

# %%
df.boxplot()
# Out:
# <AxesSubplot:>

# %%
df.plot.hist(alpha=0.7);

# %% [markdown]
# [Kernel density estimation plots](https://en.wikipedia.org/wiki/Kernel_density_estimation) are useful for deriving a smooth continuous function from a given sample.

# %%
df.plot.kde()
# Out:
# <frozen importlib._bootstrap>:228: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ### pandas.plotting

# %% [markdown]
# [Iris flower data set](https://en.wikipedia.org/wiki/Iris_flower_data_set)

# %%
iris = pd.read_csv('iris.csv')
iris.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth         Name
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %%
pd.plotting.scatter_matrix(iris);

# %% [markdown]
# ### Task 4
# Prepare a pie plot that displays how many irises are in each group (setosa, versicolor, virginica).
#
# **Note:** Before you plot the chart, you may want to prepare (group and aggregate) the data.

# %%
# Enter your code here

# %% [markdown]
# # Seaborn

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
np.random.seed(1234)

v1 = pd.Series(np.random.normal(0,10,1000), name='v1')
v2 = pd.Series(2*v1 + np.random.normal(60,15,1000), name='v2')

# %%
plt.figure()
plt.hist(v1, alpha=0.7, bins=np.arange(-50, 150, 5), label='v1')
plt.hist(v2, alpha=0.7, bins=np.arange(-50, 150, 5), label='v2')
plt.legend()
# Out:
# <div id='a6c698f8-9dde-4e2d-bad4-c3c7ea2aed3b'></div>

# %% [markdown]
# ## Joint plots

# %% [markdown]
# You can manipulate `seaborn` charts using `matplotlib.pyplot` code.

# %% [markdown]
# #### Hexabin plot

# %% [markdown]
# ## Pairplot

# %% [markdown]
# ## Violin Plot

# %% [markdown]
# ### Task 5
# Prepare a jointplot (`kde` type) that shows relation between the length and width of petals for the entire iris dataset.

# %%
# Enter your code here
