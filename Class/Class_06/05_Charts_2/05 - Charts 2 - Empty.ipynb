# %% [markdown]
# <center>
# <h1>Python and Pandas - Introduction</h1>
# <h2>
# Charts - part 2
# </h2>
# Based on "Applied Plotting, Charting & Data Representation in Python" (Coursera)
# </center>

# %% [markdown]
# ## Subplots

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np

# %%
plt.figure()
plt.subplot(1, 2, 1)
linear_data = np.arange(1, 9)
plt.plot(linear_data, '-o')
exponential_data = linear_data ** 2

plt.subplot(1, 2, 2)
plt.plot(exponential_data, '-o')

# %%
plt.figure()
ax1 = plt.subplot(1, 2, 1)
plt.plot(linear_data, 'o')

plt.subplot(1, 2, 2, sharey = ax1)  # 'sharey' control the scale
plt.plot(exponential_data, '-x')

# %% [markdown]
# Same scale on y axes

# %%
fig, (
    (ax1, ax2, ax3),
    (ax4, ax5, ax6),
    (ax7, ax8, ax9)
) = plt.subplots(3, 3, sharex = True, sharey=True)

ax5.plot(linear_data, '-o')

# %% [markdown]
# ### More charts

# %% [markdown]
# ### Task 1
# Prepare the chart with two subplots (bar plots) that present data1 and data2 lists.
# - Subplots shall be arranged vertically (the second one below the first one)
# - Subplots shall share X axis
# - Add y labels ("Data 1" and "Data 2") to subplots

# %%
data1 = [2, 3, 5, 1, 2, 5, 2]
data2 = [3, 4, 1, -2, -1, 2, 1]

# %%
# Enter your code here
pos = np.arange(len(data1))
fig, (ax1, ax2) = plt.subplots(2, 1)
ax1.bar(pos, data1)
ax1.set_ylabel('Data 1')

ax2.bar(pos, data2)
ax2.set_ylabel('Data 2')
# Out:
# Text(0, 0.5, 'Data 2')

# %% [markdown]
# ## Histograms

# %%
plt.figure()
sample = np.random.normal(loc=0.0, scale=1.0, size=10000)
ax1 = plt.subplot(121)
plt.hist(sample)

ax2 = plt.subplot(122, sharey = ax1)
plt.hist(sample, bins=20)
# Out:
# (array([   2.,    9.,   26.,   56.,  139.,  279.,  510.,  836., 1118.,
#         1401., 1462., 1394., 1134.,  766.,  431.,  240.,  129.,   49.,
#           15.,    4.]),
#  array([-3.87364879, -3.50105999, -3.12847118, -2.75588238, -2.38329358,
#         -2.01070477, -1.63811597, -1.26552717, -0.89293836, -0.52034956,
#         -0.14776075,  0.22482805,  0.59741685,  0.97000566,  1.34259446,
#          1.71518327,  2.08777207,  2.46036087,  2.83294968,  3.20553848,
#          3.57812728]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# ## Box plots

# %% [markdown]
# ##### Prepare and analyze data

# %%
import pandas as pd
normal_sample = np.random.normal(loc=0.0, scale=1.0, size=10000)
random_sample = np.random.random(size=10000)
gamma_sample = np.random.gamma(2, size=10000)

df = pd.DataFrame({'normal': normal_sample, 
                   'random': random_sample, 
                   'gamma': gamma_sample})

df.describe()
# Out:
#              normal        random         gamma
# count  10000.000000  10000.000000  10000.000000
# mean      -0.003577      0.501584      1.969459
# std        0.994394      0.290333      1.383272
# min       -4.223151      0.000042      0.005097
# 25%       -0.673925      0.247778      0.945094
# 50%       -0.026448      0.503382      1.662062
# 75%        0.664911      0.756565      2.662780
# max        3.729768      0.999885     11.378206

# %% [markdown]
# ### Task 2
# Prepare the chart with 3 subplots (histograms) that contain data from `df` dataframe.
# - Histograms shall be arranged horizontally (in one row)
# - Histograms shall contain 25 bins
# - Histograms shall share y axis
# - Histograms shall have titles

# %%
# Enter your code here
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, sharey = True)
ax1.hist(normal_sample, bins = 25)
ax1.set_title('normal hist')

ax2.hist(random_sample, bins = 25)
ax2.set_title('random hist')

ax3.hist(gamma_sample, bins = 25)
ax3.set_title('gamma hist')
# Out:
# Text(0.5, 1.0, 'gamma hist')

# %% [markdown]
# ##### Box Plot

# %%
plt.figure()
plt.boxplot(df['normal'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x25e8e8b2a00>,
#   <matplotlib.lines.Line2D at 0x25e8e8b2cd0>],
#  'caps': [<matplotlib.lines.Line2D at 0x25e8e8b2fa0>,
#   <matplotlib.lines.Line2D at 0x25e8e8c02b0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x25e8e8b2700>],
#  'medians': [<matplotlib.lines.Line2D at 0x25e8e8c0580>],
#  'fliers': [<matplotlib.lines.Line2D at 0x25e8e8c0850>],
#  'means': []}

# %% [markdown]
# Default size of the whisker is equal to 1.5 * IQR (InterQuartile Range)

# %%
plt.figure()
plt.boxplot(df['normal'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x25e8e91dc40>,
#   <matplotlib.lines.Line2D at 0x25e8e91df10>],
#  'caps': [<matplotlib.lines.Line2D at 0x25e8e92c220>,
#   <matplotlib.lines.Line2D at 0x25e8e92c4f0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x25e8e91d970>],
#  'medians': [<matplotlib.lines.Line2D at 0x25e8e92c7c0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x25e8e92ca90>],
#  'means': []}

# %% [markdown]
# Whiskers can be set as relative values

# %%
plt.figure()
plt.boxplot(df['normal'], whis=[0.1, 99.9])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x25e8e985e50>,
#   <matplotlib.lines.Line2D at 0x25e8e993160>],
#  'caps': [<matplotlib.lines.Line2D at 0x25e8e993430>,
#   <matplotlib.lines.Line2D at 0x25e8e993730>],
#  'boxes': [<matplotlib.lines.Line2D at 0x25e8e985b80>],
#  'medians': [<matplotlib.lines.Line2D at 0x25e8e993a00>],
#  'fliers': [<matplotlib.lines.Line2D at 0x25e8e993cd0>],
#  'means': []}

# %% [markdown]
# Boxplots are often used to display different distributions at the same time.

# %%
plt.figure()
plt.boxplot([df['normal'], df['random'], df['gamma']], whis=[0, 100])
plt.xticks(ticks = [1, 2, 3], labels=df.columns)
# Out:
# ([<matplotlib.axis.XTick at 0x25e8e9c9f10>,
#   <matplotlib.axis.XTick at 0x25e8e9c9ee0>,
#   <matplotlib.axis.XTick at 0x25e8e9f90a0>],
#  [Text(1, 0, 'normal'), Text(2, 0, 'random'), Text(3, 0, 'gamma')])

# %% [markdown]
# #### Task 3
# Add title and x tick labels to the chart above. Use column names from `df` Dataframe as x tick tables.

# %%
# Enter your code here

# %% [markdown]
# ## Pandas

# %%
import pandas as pd

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
# use the 'seaborn-colorblind' style
plt.style.use('seaborn-colorblind')

# %% [markdown]
# ### DataFrame.plot

# %%
np.random.seed(123)

df = pd.DataFrame({'A': np.random.randn(365).cumsum(0), 
                   'B': np.random.randn(365).cumsum(0) + 20,
                   'C': np.random.randn(365).cumsum(0) - 20}, 
                  index=pd.date_range('1/1/2019', periods=365))
df.head()
# Out:
#                    A          B          C
# 2019-01-01 -1.085631  20.059291 -20.230904
# 2019-01-02 -0.088285  21.803332 -16.659325
# 2019-01-03  0.194693  20.835588 -17.055481
# 2019-01-04 -1.311601  21.255156 -17.093802
# 2019-01-05 -1.890202  21.462083 -19.518638

# %%
df.plot();

# %% [markdown]
# We can select which plot we want to use by passing it into the 'kind' parameter.

# %%
df.plot('A', 'B', kind='scatter');

# %% [markdown]
# #### Types of plots
# - Pandas offers different types of plots
# - instead of using argument `kind`, you can use `DataFrame.plot.kind` syntax.
#
# ##### list of available types:
# - `'line'` : line plot (default)
# - `'bar'` : vertical bar plot
# - `'barh'` : horizontal bar plot
# - `'hist'` : histogram
# - `'box'` : boxplot
# - `'kde'` : Kernel Density Estimation plot
# - `'density'` : same as 'kde'
# - `'area'` : area plot
# - `'pie'` : pie plot
# - `'scatter'` : scatter plot
# - `'hexbin'` : hexbin plot

# %% [markdown]
# Create a scatterplot from columns `A` (x axis) and `C` (y axis) that changes color and size of the dots based on the data from column `B`.

# %%
df.plot.scatter('A', 'C', c='B', s=df['B'], colormap='viridis')
# Out:
# <AxesSubplot:xlabel='A', ylabel='C'>

# %% [markdown]
# `DataFrame.plot` is using `matplotlib.pyplot`. You can modify the `DataFrame.plot` charts in the same way that you modify `pyplot` charts.

# %%
# ax = df.plot.scatter('A', 'C', c='B', s=df['B'], colormap='viridis')
# ax.set_aspect('euqal')

# %% [markdown]
# ### More `df.plot` examples

# %%
df.boxplot()
# Out:
# <AxesSubplot:>

# %%
df.plot.hist(alpha=0.7);

# %% [markdown]
# [Kernel density estimation plots](https://en.wikipedia.org/wiki/Kernel_density_estimation) are useful for deriving a smooth continuous function from a given sample.

# %%
df.plot.kde()
# Out:
# <frozen importlib._bootstrap>:228: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ### pandas.plotting

# %% [markdown]
# [Iris flower data set](https://en.wikipedia.org/wiki/Iris_flower_data_set)

# %%
iris = pd.read_csv('iris.csv')
iris.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth         Name
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %%
pd.plotting.scatter_matrix(iris);

# %% [markdown]
# ### Task 4
# Prepare a pie plot that displays how many irises are in each group (setosa, versicolor, virginica).
#
# **Note:** Before you plot the chart, you may want to prepare (group and aggregate) the data.

# %%
# Enter your code here

# %% [markdown]
# # Seaborn

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
np.random.seed(1234)

v1 = pd.Series(np.random.normal(0,10,1000), name='v1')
v2 = pd.Series(2*v1 + np.random.normal(60,15,1000), name='v2')

# %%
plt.figure()
plt.hist(v1, alpha=0.7, bins=np.arange(-50, 150, 5), label='v1')
plt.hist(v2, alpha=0.7, bins=np.arange(-50, 150, 5), label='v2')
plt.legend()

# %% [markdown]
# ## Joint plots

# %%
sns.jointplot(v1, v2, alpha=0.4);
# Out:
# g:\Anaconda\envs\bigData\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# You can manipulate `seaborn` charts using `matplotlib.pyplot` code.

# %%
grid = sns.jointplot(v1, v2, alpha=.4)
grid.ax_joint.set_aspect('equal')
# Out:
# g:\Anaconda\envs\bigData\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# #### Hexabin plot

# %%
# hexabin plot shows the density of scatter, especially
sns.jointplot(v1, v2, kind='hex');
# Out:
# g:\Anaconda\envs\bigData\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.jointplot(v1, v2, kind='kde', space=0)
# Out:
# g:\Anaconda\envs\bigData\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
iris = pd.read_csv('iris.csv')
iris.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth         Name
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %% [markdown]
# ## Pairplot

# %%
# pairplot help us find some linear relationship
sns.pairplot(iris, hue='Name', diag_kind='kde', size=1)
# Out:
# g:\Anaconda\envs\bigData\lib\site-packages\seaborn\axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## Violin Plot

# %%
plt.figure(figsize=(8,6))
plt.subplot(121)
sns.swarmplot('Name', 'PetalLength', data=iris)
plt.subplot(122)
sns.violinplot('Name', 'PetalLength', data=iris)
# Out:
# g:\Anaconda\envs\bigData\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# g:\Anaconda\envs\bigData\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 8.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# g:\Anaconda\envs\bigData\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Name', ylabel='PetalLength'>

# %% [markdown]
# inside of violinplot is boxplot

# %%
f = plt.figure()
sns.violinplot(y='PetalLength',data=iris)
# Out:
# <AxesSubplot:ylabel='PetalLength'>

# %% [markdown]
# ### Task 5
# Prepare a jointplot (`kde` type) that shows relation between the length and width of petals for the entire iris dataset.

# %%
# Enter your code here
sns.jointplot(iris['PetalLength'], iris['PetalWidth'], kind='kde')
# Out:
# g:\Anaconda\envs\bigData\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
